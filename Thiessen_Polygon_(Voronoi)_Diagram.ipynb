# %% [markdown]
# <a href="https://colab.research.google.com/github/1kaiser/test2023/blob/main/Thiessen_Polygon_(Voronoi)_Diagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scipy

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi

# Generate random data points
np.random.seed(0)
points = np.random.rand(10, 2)  # 10 random points

# Create Voronoi diagram
vor = Voronoi(points)

# Plot Voronoi polygons and data points
for region in vor.regions:
    if not -1 in region and len(region) > 0:
        polygon = [vor.vertices[i] for i in region]
        plt.fill(*zip(*polygon), alpha=0.5)

plt.plot(points[:, 0], points[:, 1], 'ro')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Thiessen Polygon (Voronoi) Diagram')
plt.legend()

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
