# %% [markdown]
# <a href="https://colab.research.google.com/github/1kaiser/test2023/blob/main/Hypsometric_curve_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**[Hypsometric spreadsheet](https://docs.google.com/spreadsheets/d/1yOFEmha__J8yDo0gUBbnZ4m6xM_I_wQ0K6xSldy0Qag/edit?usp=sharing)**

# %%
A = [[0.07,1,1,1,1],
[0.14,1,1,1,1],
[0.21,0.998547219760427,0.996781688845681,0.994252351201337,0.997711427459978],
[0.29,0.979948192403628,0.954421042096654,0.907173882561707,0.966907597576185],
[0.36,0.846471992648128,0.664797221069181,0.466777494515169,0.747109748748256],
[0.43,0.639021872935887,0.318507132075292,0.240591154897806,0.431312831151623],
[0.50,0.422125936530538,0.108999384358735,0.14840027472676,0.172043200767564],
[0.57,0.25065398332713,0.0275316648395967,0.101632079516131,0.061816008210953],
[0.64,0.133411286957194,0.0103368091585591,0.0831953759562238,0.0177146064063972],
[0.71,0.0540766090287392,0.00914471704212291,0.0740316361085355,0.00403001235264325],
[0.79,0.0101702791961205,0.00914471704212291,0.0695618843875612,0.00217216736737613],
[0.86,0.00123050384270878,0.00914471704212291,0.0651977212921472,0.00212867397837126],
[0.93,0.00120540848033175,0.00914471704212291,0.0593445421076243,0.00212867397837126],
[1.00,0.00120540848033175,0.00914471704212291,0.0552835891373272,0.00212867397837126],]

# %%
len(A)
# Out:
# 14

# %%
x =[]
JAN =[]
FEB =[]
MAR =[]
APR =[]
for i in range(len(A)):
  print(A[i])
  x.append(A[i][0])
  JAN.append(A[i][1])
  FEB.append(A[i][2])
  MAR.append(A[i][3])
  APR.append(A[i][4])
# Out:
# [0.07, 1, 1, 1, 1]
# [0.14, 1, 1, 1, 1]
# [0.21, 0.998547219760427, 0.996781688845681, 0.994252351201337, 0.997711427459978]
# [0.29, 0.979948192403628, 0.954421042096654, 0.907173882561707, 0.966907597576185]
# [0.36, 0.846471992648128, 0.664797221069181, 0.466777494515169, 0.747109748748256]
# [0.43, 0.639021872935887, 0.318507132075292, 0.240591154897806, 0.431312831151623]
# [0.5, 0.422125936530538, 0.108999384358735, 0.14840027472676, 0.172043200767564]
# [0.57, 0.25065398332713, 0.0275316648395967, 0.101632079516131, 0.061816008210953]
# [0.64, 0.133411286957194, 0.0103368091585591, 0.0831953759562238, 0.0177146064063972]
# [0.71, 0.0540766090287392, 0.00914471704212291, 0.0740316361085355, 0.00403001235264325]
# [0.79, 0.0101702791961205, 0.00914471704212291, 0.0695618843875612, 0.00217216736737613]
# [0.86, 0.00123050384270878, 0.00914471704212291, 0.0651977212921472, 0.00212867397837126]
# ...

# %%
y1 =[[0,1],
[0.024,0.96],
[0.038,0.917],
[0.054,0.864],
[0.076,0.831],
[0.111,0.785],
[0.149,0.762],
[0.196,0.735],
[0.237,0.712],
[0.278,0.695],
[0.313,0.682],
[0.348,0.675],
[0.389,0.662],
[0.421,0.659],
[0.456,0.646],
[0.497,0.636],
[0.535,0.623],
[0.566,0.619],
[0.595,0.613],
[0.63,0.603],
[0.652,0.599],
[0.687,0.586],
[0.709,0.579],
[0.741,0.57],
[0.769,0.563],
[0.797,0.55],
[0.823,0.54],
[0.848,0.533],
[0.873,0.517],
[0.896,0.503],
[0.921,0.493],
[0.946,0.466],
[0.962,0.454],
[0.968,0.242],
[0.978,0.107],
[0.986,0.089],
[1,0],]

m1 =[[0,1],
[0.024,0.854],
[0.035,0.791],
[0.047,0.725],
[0.06,0.679],
[0.073,0.642],
[0.085,0.619],
[0.101,0.583],
[0.117,0.55],
[0.149,0.51],
[0.174,0.487],
[0.199,0.467],
[0.228,0.44],
[0.263,0.424],
[0.342,0.391],
[0.383,0.377],
[0.424,0.361],
[0.453,0.351],
[0.491,0.334],
[0.516,0.328],
[0.544,0.321],
[0.611,0.298],
[0.642,0.291],
[0.674,0.278],
[0.706,0.268],
[0.741,0.258],
[0.766,0.252],
[0.797,0.242],
[0.823,0.232],
[0.851,0.222],
[0.883,0.199],
[0.911,0.192],
[0.937,0.172],
[0.959,0.156],
[0.972,0.142],
[0.983,0.123],
[1,0],]

o1 =[[0,1],
[0.024,0.795],
[0.035,0.719],
[0.041,0.623],
[0.057,0.483],
[0.079,0.401],
[0.095,0.361],
[0.111,0.328],
[0.13,0.301],
[0.149,0.275],
[0.168,0.252],
[0.225,0.209],
[0.241,0.199],
[0.259,0.192],
[0.278,0.182],
[0.297,0.175],
[0.316,0.169],
[0.361,0.156],
[0.386,0.146],
[0.443,0.132],
[0.462,0.129],
[0.478,0.123],
[0.513,0.113],
[0.535,0.106],
[0.56,0.103],
[0.62,0.093],
[0.674,0.086],
[0.696,0.079],
[0.734,0.076],
[0.756,0.073],
[0.775,0.07],
[0.861,0.053],
[0.88,0.053],
[0.905,0.05],
[0.962,0.04],
[0.979,0.026],
[1,0],]

# %%
youthx = []
youthy = []
maturex = []
maturey = []
oldx =[]
oldy =[]

for i in range(len(y1)):
  youthx.append(y1[i][0])
  youthy.append(y1[i][1])

for i in range(len(m1)):
  maturex.append(m1[i][0])
  maturey.append(m1[i][1])

for i in range(len(o1)):
  oldx.append(o1[i][0])
  oldy.append(o1[i][1])

# %%
import matplotlib.pyplot as plt
import numpy as np

# # Data for plotting
# x = np.arange(0.0, 2.0, 0.01)
# y = 1 + np.sin(2 * np.pi * t)
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(youthx, youthy , c='green', label="youth")
ax.plot(maturex, maturey , c='blue', label="mature")
ax.plot(oldx, oldy , c='black', label="old")

ax.plot(JAN , x, c='r', label="JANUARY")
ax.plot(FEB , x, c='r', label="FEBRUARY")
ax.plot(MAR , x, c='r', label="MARCH")
ax.plot(APR , x, c='r', label="APRIL")
ax.legend(loc='upper right')


ax.set(xlabel='Relative Area', ylabel='Relative Height',
       title='Snow Cover Hypsometric curve')
ax.grid()

fig.savefig("test.png")
plt.show()
